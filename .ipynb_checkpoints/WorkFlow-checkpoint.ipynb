# %% [markdown]
# ### Fetch Million Song DB Songs and Artists

# %%
import os
import sys
import time
import glob
import datetime
import sqlite3
import tables
import pandas as pd 
import numpy as np 

# path to the Million Song Dataset subset (uncompressed)
msd_subset_path='MillionSongSubset'
msd_subset_data_path=os.path.join(msd_subset_path,'data')
msd_subset_addf_path=os.path.join(msd_subset_path,'AdditionalFiles')
assert os.path.isdir(msd_subset_path),'wrong path' 

conn = sqlite3.connect(os.path.join(msd_subset_addf_path,
                                    'subset_track_metadata.db'))
q = "SELECT title, artist_name FROM songs"
all_songs = pd.read_sql_query(q, conn)

# %%
all_songs.head()
# Out:
#                     title              artist_name
# 0                                   Sébastien Roch
# 1              -start ID-  The Mad Capsule Markets
# 2           '57 Chevrolet         Billie Jo Spears
# 3        'Round the Wheel                 DJ Harry
# 4  'Ti Monde (LP Version)               BeauSoleil

# %% [markdown]
# ### Query Spotify API

# %%
# def spotify_request(url, token, params):
#     """Make a Spotify request using the specified token and parameters."""
#     r = requests.get(url, headers={'Authorization': 'Bearer {}'.format(token['access_token'])},
#                      params=params)
#     return r.json()

# def build_query(song_df):
#     # drop missing rows
#     song_df.replace(r'', np.nan, regex=True, inplace=True)
#     song_df.dropna(inplace=True)
    
#     query_terms = []
#     for index, row in song_df.iterrows():
#         query_terms.append((quote(row[1]), quote(row[0])))
#     return query_terms

# # get track id by querying song and artist
# def track_id(track, artist):
#     r = requests.get("https://api.spotify.com/v1/search?q=track:{0}%20artist:{1}&type=track".format(track, artist), 
#                      headers={'Authorization': 'Bearer {}'.format(token['access_token'])})
#     if r.status_code == 200:
#         return r.json()
#     else:
#         raise IOError('Spotify API request unsuccessful. Status code:{}'.format(r.status_code))

# # get track analysis
# def track_info(id):
#     r = requests.get("https://api.spotify.com/v1/audio-analysis/{0}".format(id), 
#                      headers={'Authorization': 'Bearer {}'.format(token['access_token'])})
#     return r.json()

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-85-a6a62fbdda0d> in <module>()
# ----> 1 track_id('blah','blach')
#
# <ipython-input-84-873e5b3686f8> in track_id(track, artist)
#      43         return r.json()
#      44     else:
# ---> 45         raise IOError('Spotify API request unsuccessful. Status code:{}'.format(r.status_code))
#      46
#      47 # get track analysis
#
# OSError: Spotify API request unsuccessful. Status code:401

# %%
secrets = load_secrets()
token = get_token(secrets)

# %%
track_ids = []
not_found = []
for song in track_and_artist[:100]:
    try:
        track_ids.append(track_id(song[0], song[1])['tracks']['items'][0]['id'])
    except IOError as e:
#         print (e)
        if e.message[-3:] == '401':
            not_found.append(song)
# Out:
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401
# Spotify API request unsuccessful. Status code:401

# %%
len(not_found)
# Out:
# 31

# %%
track_data = {}
for ident in track_ids:
    track_data[ident] = track_info(ident)

# %%
len(track_data.keys())
# Out:
# 69

# %%
import json
json.dumps(track_data['0nbm4bvneAGlrp5wZKRHT8']).__len__()
# Out:
# 310460

# %% [markdown]
# ### Reading in Tracks from Text File

# %%
song_df = pd.read_csv('unique_tracks.txt', 
                      sep="<SEP>", 
                      header=None, 
                      engine='python', 
                      names=[0,1,'artist', 'track'])[['artist','track']]

# %%
song_df.head()
# Out:
#              artist              track
# 0  Faster Pussy cat       Silent Night
# 1  Karkkiautomaatti        Tanssi vaan
# 2    Hudson Mohawke  No One Could Ever
# 3       Yerba Brava      Si Vos Querés
# 4        Der Mystic   Tangle Of Aspens

# %%
queries = build_query(song_df)

# %%
queries
# Out:
# [('Silent%20Night', 'Faster%20Pussy%20cat'),
#  ('Tanssi%20vaan', 'Karkkiautomaatti'),
#  ('No%20One%20Could%20Ever', 'Hudson%20Mohawke'),
#  ('Si%20Vos%20Quer%C3%A9s', 'Yerba%20Brava'),
#  ('Tangle%20Of%20Aspens', 'Der%20Mystic'),
#  ('Symphony%20No.%201%20G%20minor%20%22Sinfonie%20Serieuse%22/Allegro%20con%20energia',
#   'David%20Montgomery'),
#  ('We%20Have%20Got%20Love', 'Sasha%20/%20Turbulence'),
#  ('2%20Da%20Beat%20Ch%27yall', 'Kris%20Kross'),
#  ('Goodbye', 'Joseph%20Locke'),
#  ('Mama_%20mama%20can%27t%20you%20see%20%3F',
#   'The%20Sun%20Harbor%27s%20Chorus-Documentary%20Recordings'),
#  ('L%27antarctique', '3%20Gars%20Su%27l%20Sofa'),
#  ('El%20hijo%20del%20pueblo', 'Jorge%20Negrete'),
#  ('Cold%20Beer%20feat.%20Prince%20Metropolitan', 'Danny%20Diablo'),
#  ('Pilots', 'Tiger%20Lou'),
#  ('N%20Gana', 'Waldemar%20Bastos'),
#  ('006', 'Lena%20Philipsson'),
#  ('%28Looking%20For%29%20The%20Heart%20Of%20Saturday', 'Shawn%20Colvin'),
#  ('Ethos%20of%20Coercion', 'Dying%20Fetus'),
#  ('Rock-N-Rule', 'Emery'),
#  ('La%20bola%20extra', 'Los%20Ronaldos'),
#  ('I%20Made%20It%20Over', 'Rev.%20Timothy%20Wright'),
#  ('Debussy%20%3A%2012%20Etudes%20%3A%20VI%20Pour%20les%20huit%20doigts',
#   'Pierre-Laurent%20Aimard'),
#  ('Nervous', 'Nicolette'),
#  ('In%20The%20Journey', 'Martin%20Sexton'),
#  ('Fuckin%20Ethic%20People%20%28999%29', 'Craze'),
#  ('Tu%20Vida%20Con%20La%20M%C3%ADa', 'Christian%20Castro'),
#  ('I%27m%20Ready', 'Aerosmith'),
#  ('Take%20As%20Needed', 'Skinlab'),
#  ('Autumn%20In%20The%20Mind%20%28Acoustic%20Version%29',
#   'Mike%20Badger%20and%20Friends'),
#  ('Tequila', 'Piotta'),
#  ('All%20For%20A%20Purpose%20%28Speak%20Life%20Album%20Version%29',
#   'Sev%20Statik'),
#  ('C%20On', 'The%20Advent'),
#  ('Raspberry%20Beret%20%28LP%20Version%29', 'Prince%20%26%20The%20Revolution'),
#  ('All%20of%20the%20same%20blood', 'Kreator'),
#  ('One%20Little%20Too%20Little', 'Hall%20Of%20Fame'),
#  ('Cockleshell%20Heroes', 'Frank%20Chacksfield'),
#  ('Trancesequence', 'Voyage'),
#  ('Wonderful%20Stash', 'Wishbone%20Ash'),
#  ('La%20filo', 'Malavoi'),
#  ('Throw%20It%20Away', 'Cobra%20Verde'),
#  ('Before%20He%20Kissed%20Me', 'Lisa%20Brokop'),
#  ('Blessed', 'The%20Emotions'),
#  ('Goa%20Amsterdam', 'Safi%20Connection'),
#  ('Disaster%20%5BDemo%20Version%5D', 'Hawthorne%20Heights'),
#  ('Night%20And%20Day', 'The%20Maytals'),
#  ('Passione', 'Neffa'),
#  ('My%20Everything%20%5BScrewed%5D%20%28feat.%20Trae%20The%20Truth%29',
#   'Lil%19%20O'),
#  ('Scream', 'Billy%20Idol'),
#  ('The%20Man%20Delusion', 'The%20Vichy%20Government'),
#  ('He%20Is%20Not%20Silent%20%28Out%20Of%20The%20Grey%20Album%20Version%29',
#   'Out%20Of%20The%20Grey'),
#  ('Pepe%20El%20Ma%C3%B1oso', 'Orquesta%20Sonara%20La%20Habana'),
#  ('Ac%C3%A9rcate%20M%C3%A1s', 'Leo%20Marini'),
#  ('Mule%20Boogie', 'Sheb%20Wooley'),
#  ('Dancing%20In%20The%20Dark', 'Diana%20Krall'),
#  ('Mad%20About%20You', 'Clifford%20T.%20Ward'),
#  ('Heartaches', 'Ray%20Conniff%3BBilly%20Butterfield'),
#  ('Pain%20Over%20Acceptance', 'Weekend%20Nachos'),
#  ('Ships%20That%20Don%27t%20Come%20In', 'Joe%20Diffie'),
#  ('Saturday%20Night%20%20%28LP%20Version%29', 'Blackfoot'),
#  ('I%20Just%20Want%20To%20Be%20With%20You%20This%20Christmas',
#   'Katie%20Armiger'),
#  ('On%20the%20Surface', 'Stemm'),
#  ('Remember%20%28Walking%20In%20The%20Sand%29', 'Aerosmith'),
#  ('Just%20Another%20Woman', 'Hot%20Lips%20Page'),
#  ('untitled', 'David%20Fridlund'),
#  ('Bakslag', 'Kultiration'),
#  ('The%20New%20Way', 'Ewigkeit'),
#  ('Suffer', 'JOHN%20DOE'),
#  ('Cit%C3%A9s%20dortoires%20%28feat.%2059%20Grammes%29', 'Alpha%205.20'),
#  ('Bring%20It', 'Tonex'),
#  ('You%20And%20I', 'Chasen'),
#  ('Sitting%20In%20My%20Window%20%28Finis%20Tasby%20BMI%29', 'Finis%20Tasby'),
#  ('Raid%20The%20Itch', 'Ogris%20Debris'),
#  ('The%20Rest%20of%20the%20Night', 'Warren%20Zevon'),
#  ('Ride', 'Andrea%20Klas'),
#  ('Passion%20Protein', 'The%20Soup%20Dragons'),
#  ('Redemption', 'Write%20This%20Down'),
#  ('Dame%20Tus%20%20Besos', 'Radio%20Macand%C3%A9'),
#  ('Don%27t%20Prolong%20the%20Agony%20%28Bonus%20Track%29', 'Claire%20Hamill'),
#  ('Dalny%20svet%20%28bonus%202003%29', 'Kruiz'),
#  ('Alice%20in%20Wonderland%3A%20Act%20I%3A%20The%20Caucus%20Race',
#   'Carl%20Davis'),
#  ('Le%20mauvais%20coton', 'Brigitte%20Fontaine'),
#  ('Love%20Can%20Change%20feat.%20Nadine%20Sutherland', 'Abijah'),
#  ('Subtek', 'Hex'),
#  ('Dream%20Of%20Love', 'X-Perience'),
#  ('Lucy%20Fears%20the%20Morning%20Star', 'Diablo%20Swing%20Orchestra'),
#  ('Fool%20on%20the%20Hill', 'John%20Williams'),
#  ('Baiting%20the%20Public', 'Fucked%20Up'),
#  ('Death%20Acceptor', 'Drexel'),
#  ('Wipeout', 'The%20Surfaris'),
#  ('Fick%20uns', 'Kool%20Savas'),
#  ('Wir%20Sind%20Die%20Jungs%20feat.%20Din%20%26%20Smexer', 'Prinz%20Porno'),
#  ('Make%20Dat%20Monet', 'Lord%20T%20%26%20Eloise'),
#  ('Two%20Legged%20Sheep', 'Kingdom%20Come'),
#  ('Chi%20Sei%20Adesso', 'Gemelli%20Diversi'),
#  ('Stuck%20On%20My%20Vision', 'Alice%20In%20Videoland'),
#  ('Joku%20muu', 'Kristian%20Meurman'),
#  ('Whaleface%20%28Instrumental%29', 'Felt'),
#  ('Brown%20Paper%20Bag', 'Gangster%20Fun'),
#  ('You%20Needed%20Me', 'Roger%20Whittaker'),
#  ('Pacey%20Singer', 'A.Human'),
#  ('Superstition', 'Beck_%20Bogert_%20Appice'),
#  ('Ride', 'Ti%C3%ABsto'),
#  ('Endangered%20Species%20%28Tales%20From%20The%20Darkside%29%20%28Remix%29%20%28Explicit%29%20%28Feat.%20Chuck%20D%29',
#   'Ice%20Cube%20Featuring%20Chuck%20D'),
#  ('Summer%20Of%20My%20Life', 'Archie%20Roach'),
#  ('Foggy%20Mountain%20Breakdown',
#   'Lester%20Flatt%20/%20Earl%20Scruggs%20/%20The%20Foggy%20Mountain%20Boys'),
#  ('Sonata%20No.%2010%20Op.%2070', 'Mikhail%20Pletnev'),
#  ('Red%20Ramona', 'Janette%20Slack'),
#  ('What%20Matters%20Is%20Just%20You', 'Luis%20Eduardo%20Aute'),
#  ('Southern%20Comfort', 'Lonesome%20River%20Band'),
#  ('Something%20From%20Nothing', 'Retard-O-Bot'),
#  ('Half%20Light', 'Michael%20Whalen'),
#  ('Bonus%20Track', 'Kaze'),
#  ('High%20Low%20And%20In%20Between', 'Mark%20Wills'),
#  ('Detalles', 'Roberto%20Carlos'),
#  ('Rock%20Can%27t%20Last%20Forever%20%20%28You%20Hate%20Me%20Hate%20Music%20Album%20Version%29',
#   'Fine%20China'),
#  ('Get%20Along%20%28Feat%3A%20Pace%20Won%29%20%28Instrumental%29',
#   'Morcheeba'),
#  ('Caravan', 'Richard%20%22Groove%22%20Holmes'),
#  ('Just%20Is', 'Lamb'),
#  ('The%20Life%20That%20I%20Never%20Had', 'Sektosixo'),
#  ('Inside%20Your%20Dreams', 'DJ%20Markitos'),
#  ('Hot%20%28Album%20Version%29', 'The%20Beatnuts'),
#  ('Have%20It%20All', 'Ronski%20Speed%20presents%20Sun%20Decade'),
#  ('Words%20-%20Re-Recording', 'Jeannie%20C.%20Riley'),
#  ('Viejo', 'Bacilos'),
#  ('Victims%20of%20the%20Riddle%20%5BVivisection%5D', 'Toyah'),
#  ('Kama%20Sutra', 'The%20Wolfmen'),
#  ('E%20non%20lo%20scorder%C3%B2', 'Fausto%20Leali'),
#  ('What%20Can%20I%20Do%3F', 'Link%2080'),
#  ('Whats%20up%20with%20the%20Underground', 'Linkwood'),
#  ('Pacific%20Sunrise', 'Spyro%20Gyra'),
#  ('Gnostalgia', 'White%20Willow'),
#  ('Sin%20Sin%20Sin%20%28Sentience%20Loney%20Mix%29', 'Robbie%20Williams'),
#  ('Bihac', 'Prager%20Handgriff'),
#  ('Hard%20Life%20Feat%20Raw%20Breed', 'Marc%20Live'),
#  ('Memories%20Of%20Love%20-%20Original%20Mix', 'Paul%20Miller'),
#  ('Praise_%20My%20Soul_%20The%20King%20Of%20Heaven', 'American%20Boychoir'),
#  ('Edward%20Smith', 'Thought%20Industry'),
#  ('Dark%20Country', 'Red%20Animal%20War'),
#  ('Highway%20Paved%20With%20Pain', 'Lonesome%20River%20Band'),
#  ('End%20Of%20The%20Beginning%20%28Album%20Version%29', 'Jason%20Becker'),
#  ('Britannia', 'Sunscreem'),
#  ('I%27m%20About%20To%20Do%20Something%20%28That%20I%27m%20Gonna%20Regret%29',
#   'Motormark'),
#  ('Ring%20Road', 'Underworld'),
#  ('L%19Esperanza', 'Airscape'),
#  ('That%20Crutch', 'Neal%20Morse'),
#  ('I%20Say%20A%20Little%20Prayer', 'Al%20Green'),
#  ('Dawning%20Star', 'The%20Muffins'),
#  ('Irreplaceable', 'The%20Funky%20Lowlives'),
#  ('AcroyearII', 'Autechre'),
#  ('And%20Then%20You%20Went%20Away', 'Brian%20Vander%20Ark'),
#  ('You%20Don%27t%20Know%20What%20You%27re%20Doing', 'Debbie%20Davies'),
#  ('Touched%20%28Intro%3A%20From%20%27That%20Winter%27%20By%20Pamela%20Gillilan%29',
#   'Boo%20Hewerdine'),
#  ('Day', 'Katatonia'),
#  ('En%20oo%20koskaan%20tavannut', 'Zen%20Cafe'),
#  ('B15%20Apna%20Sangheet%20Sings%20Apna%20Sangsheet_%20Ruled%20By%20The%20Mob',
#   'DJ%20Rupture'),
#  ('Militant%20Musicfreaks', 'Warlocks'),
#  ('The%20Color%20Of%20The%20Water%20/%20Dreaming%20Of%20The%20Future',
#   'Luis%20Bacalov'),
#  ('Nothing%20More%20to%20Say', 'AJP'),
#  ('Rock%27n%27roll%20vengeance', 'La%20Souris%20D%C3%A9glingu%C3%A9e'),
#  ('Qui%20%3F%20%28version%20baba%20cool%29', 'Mickey%203D'),
#  ('Four%20Horses', 'William%20Lee%20Ellis'),
#  ('Laurie%20Ann', 'Glen%20Glenn'),
#  ('N%C3%A4ckaspel', 'Sofia%20Karlsson'),
#  ('Get%20Up%20%28Club%20Mix%29', 'Krid%20P'),
#  ('Melodia%20Do%20Amor', 'Golden%20Boys'),
#  ('Whatcha%20Gonna%20Do%20When%20Your%20Number%27s%20Up%3F%20%20%20%28The%20Best%20We%20Could%20Find%20Album%20Version%29',
#   'STEVE%20TAYLOR'),
#  ('Waste%20of%20Time', 'Junkyard'),
#  ('Deep%20in%20the%20night', 'JK'),
#  ('Skase', 'Christos%20Dantis'),
#  ('Make%20Her%20Feel%20Good', 'Teairra%20Mar%C3%AD'),
#  ('Radio%20Was%20Unplugged', 'Silent%20Kids'),
#  ('Margaret%20On%20The%20Guillotine%20%28LP%20Version%29', 'Morrissey'),
#  ('At%20the%20Ball_%20That%27s%20All', 'Laurel%20%26%20Hardy'),
#  ('Presence%20Of%20The%20Dead%20%28Album%20Version%29', 'Pestilence'),
#  ('The%20Art%20of%20the%20Fugue_%20BWV%201080/Contrapunctus%20XIV',
#   'Juilliard%20String%20Quartet'),
#  ('Love%20Has%20A%20Diameter', 'Biffy%20Clyro'),
#  ('Communion', 'Mental%20Overdrive'),
#  ('No%20quarter', 'Exhumed'),
#  ('Rowboat', 'Johnny%20Cash'),
#  ('Captain_%20My%20Captain', 'I_%20Synthesist'),
#  ('Home%20In%20Your%20Heart', 'Derek%20Trucks%3BSolomon%20Burke'),
#  ('Pourquoi', 'Anael%20Miller'),
#  ('Sold%20Out%20Of%20Love', 'New%20York%20Rel-X'),
#  ('He%27s%20So%20Brave', 'Sensations'),
#  ('Rave%20Up', 'Bad%20Dreams%20Fancy%20Dress'),
#  ('02.17%20AM', 'Blue%20Foundation'),
#  ('She%27s%20Alright', 'The%20Real%20Kids'),
#  ('The%20Itsy%20Bitsy%20Spider', 'Dora%20The%20Explorer'),
#  ('Mirage', 'Billy%20Cobham'),
#  ('How%20Great%20Is%20Our%20King', 'EM1'),
#  ('Battery', 'Santa%20Claws%20and%20the%20Naughty%20But%20Nice%20Orchestra'),
#  ('Black%20Gold', 'Foals'),
#  ('Mary%20Beth', 'Peter%20Yarrow'),
#  ('Walk%20In%20Holy%20Ghostwood/Time%27s%20Going%20On', 'Lird%20Van%20Goles'),
#  ('When%20You%27re%20Sick%20With%20The%20Blues', 'Mississippi%20Sheiks'),
#  ('Snowflakes%20%28VeebeeO%20Remix%29', 'Jessica%20Folcker'),
#  ('Traktor', 'Visaci%20Zamek'),
#  ('I%20Can%27t%20Take%20The%20Runnings%20Ina%20Babylon%20-%20Original',
#   'BuRo'),
#  ('Smilin%27', 'Bryn%20Christopher'),
#  ('Atrevida%20Bandolera', 'Voltio'),
#  ('Distorted%20Minds', 'Hexstatic%20feat.%20Juice%20Aleem'),
#  ('Esa%20Cancion%20Nos%20Salvo', 'Travolta'),
#  ('Trend%20/%20Sprengk%C3%B6rper%20%28Medley%29%20%28Live%29',
#   'Mediengruppe%20Telekommander'),
#  ('The%20Unbeliever', 'Middle%20Distance%20Runner'),
#  ('Paper%20Doll', 'Denison%20Witmer'),
#  ('Gotta%20Go%20Home', 'Boney%20M.%202000'),
#  ('Gypsy%20Eyes', 'Michael%20Stanley%20Band'),
#  ('Valse%20Lente', 'Boston%20Pops%20Orchestra'),
#  ('Three', 'The%20Show%20is%20the%20Rainbow'),
#  ('Gridlock', 'Kill%20The%20Client'),
#  ('White%20Baby', 'Giant%20Drag'),
#  ('A%20Hole%20In%20The%20World%20%28Album%20Version%29', 'Thursday'),
#  ('The%20Journey', 'Lisa%20Lynne%20and%20Georege%20Tortorelli'),
#  ('That%27s%20Why%20I%27m%20Leaving', 'The%20Peelers'),
#  ('Your%20Heart%27s%20Not%20In%20It', 'Janie%20Fricke'),
#  ('La%20Inseminacion', 'Johnny%20Ventura'),
#  ('Willie%20Barcena', 'Willie%20Barcena'),
#  ('This%20Time%20It%27s%20Real', 'Miquel%20Brown'),
#  ('Final%20Promise%20%28World%29', 'Davol'),
#  ('Stand%20Alone%20%28Album%20Version%29', 'The%20Cult'),
#  ('If%20I%20Get%20to%20the%20Borderline', 'J.%20Tillman'),
#  ('Hit%20Medley%20Part%20Three', 'Arabesque'),
#  ('How%20You%20Livin%3F%20f/J-Live%20%26%20Grap%20Luva%20%26%20Sondia',
#   'Asheru%20And%20Blue%20Black%20Of%20The%20Unspoken%20Heard'),
#  ('Insomnomaniac', 'Joshua%20Redman'),
#  ('Tonight%20Will%20Be%20Fine', 'Leonard%20Cohen'),
#  ('Straighten%20Up%20And%20Fly%20Right%20%20%28LP%20Version%29',
#   'Linda%20Ronstadt'),
#  ('Will%20You%20Not%20Listen%3F', 'Michael%20Card'),
#  ('Kallisti%20%13%20Song%20For%20Eris', 'Floor'),
#  ('Country%20Boogie%20Fever', 'Eddie%20Jones'),
#  ('Zuviel%20Hitze', 'Falco'),
#  ('Bunion%20Blues', 'Lighnin%27%20Hopkins'),
#  ('Se%20Fosse%20Adesso', 'Perturbazione'),
#  ('Please%20Set%20Me%20At%20Ease', 'Bobbi%20Humphrey'),
#  ('What%20Would%20You%20Do%3F', 'Mary%20Louise%20Wilson'),
#  ('Killers%20And%20Killed', 'Angelus%20Apatrida'),
#  ('No%20Doubt%20About%20It%20%20%28Miracle%20Album%20Version%29',
#   'The%20Clark%20Sisters'),
#  ('Pantomime', 'Operator%20Please'),
#  ('Beautiful%20Noise', 'Spencer%20Parker'),
#  ('Nine%20Million%20Bicycles', 'Katie%20Melua'),
#  ('Call%20Me%20%28Album%20Version%29', 'Shinedown'),
#  ('Do%20You%20Know', 'The%20Cranberries'),
#  ('La%20titimania', 'Juan%20Formell%20y%20los%20Van%20Van'),
#  ('Vacuum', 'Teenage%20Bad%20Girl'),
#  ('S%C3%A4', 'Scandinavian%20Music%20Group'),
#  ('You%20Win%20Again', 'Martina%20McBride'),
#  ('Anyone%20Else%20But%20You', 'Michael%20Cera%20%26%20Ellen%20Page'),
#  ('Maia%20Sterling', 'Scott%20Glasgow'),
#  ('Wanna%20Be%20%28Explicit%20Album%20Version%29', 'Bone%20Thugs-N-Harmony'),
#  ('The%20Rain', 'Lou%20Rhodes'),
#  ('Shake%20It%20Up', 'Elizabeth%20Daily'),
#  ('I%20Cry%20%28LP%20Version%29', 'Russ%20Taff'),
#  ('Major%20Tom%20%2794%28English%20Version%29',
#   'Peter%20Schilling%20%26%20Boom-Bastic'),
#  ('Who%20I%20Am', 'Brandy'),
#  ('Escape%20From%20Rome', 'Cricco%20Castelli'),
#  ('Strikethrough', 'Peter%20Van%20Hoesen'),
#  ('Henrieta', 'Harper%20Simon'),
#  ('Your%20Arms%20Feel%20Like%20Home', '3%20Doors%20Down'),
#  ('Midnight%20Birds%20%28Sa%20Ra%20Remix%29',
#   'Medeski_%20Martin%20%26%20Wood/Sa%20Ra%20Creative%20Partners'),
#  ('Telegram%20f%C3%B6r%20en%20tennsoldat', 'Cornelis%20Vreeswijk'),
#  ('Never%20Met%20A%20German', 'Brazilian%20Girls'),
#  ('Stones%20You%20Throw', 'Career%20Suicide'),
#  ('Solaris', 'Photek'),
#  ('Oriente', 'Gilberto%20Gil'),
#  ('Perverted%20Eyelash', 'Robert%20Pollard'),
#  ('Eye%20Spy', 'The%20Race'),
#  ('Tiempo%20Al%20Tiempo', 'Marta%20Sanchez'),
#  ('Out%20Of%20My%20Head', 'Puddle%20Of%20Mudd'),
#  ('Knives%20and%20Faces', 'Raging%20Speedhorn'),
#  ('Itoshii%20Toki', 'Rie%20Tomosaka'),
#  ('Suzanne', 'Leonard%20Cohen'),
#  ('Pump%20Up%20The%20Electro%20Volume', 'DaVIP'),
#  ('Telze%27', 'Max%20Brannslokker'),
#  ('Don%27t%20Stop%20Honey%20%28feat.%20Cedric%20Burnside%29',
#   'R.L.%20Burnside'),
#  ('Scream%20My%20Name', 'Chaka%20Demus%20%26%20Pliers'),
#  ('Girl%27s%20Got%20Rhythm', 'Omar%20%26%20The%20Howlers'),
#  ('I%20Do%20It%20For%20Your%20Love', 'Jane%20Monheit'),
#  ('All%20I%20Need%20%28Key-Ab-Premiere%20Performance%20Plus%29',
#   'Bethany%20Dillon'),
#  ('Beyond%20the%20Borders%20of%20Sanity', 'YGGDRASIL'),
#  ('Microphone%20Check', 'Illegal%20Substance'),
#  ('Arruyo%20de%20Dios', 'Mar%C3%ADa%20Dolores%20Pradera%20/%20Amaya%20Uranga'),
#  ('Corcovado', 'P%20%26%20Q'),
#  ('Blow%20Up', 'Popsicle'),
#  ('Music%20Is%20My%20Business', 'Roosevelt%20Sykes'),
#  ('Tonight', 'June%20Star'),
#  ('Your%20Sweet%20Love', 'Albert%20Cummings'),
#  ('Back%20To%20Back', 'The%20Chariot'),
#  ('A%20Better%20World', 'M.I.K.E.%20vs.%20Andrew%20Bennett'),
#  ('Humppakavalier', 'Elakelaiset'),
#  ('Clambake%20Boogie', 'Big%20John%20Greer'),
#  ('Je%20Dois%20Partir', 'Ste%20Strausz'),
#  ('J%C3%BArame', 'Alejandro%20Fernandez'),
#  ('We%20Trust%20In%20The%20Name%20Of%20The%20Lord%20Our%20God%20%28Where%20Mercy%20Begins%20Album%20Version%29',
#   'Steve%20Green'),
#  ('Chi%20Ha%20Paura%20Della%20Notte%3F', 'Premiata%20Forneria%20Marconi'),
#  ('Sunrise%20%28Album%29', 'Mark%20Lanegan'),
#  ('Blow%20Ya%20Back%20Out%20%5BRadio%20Edit%5D', 'Attitude'),
#  ('Harpo%27s%20bazar', 'The%20Marx%20Brothers'),
#  ('The%20American', 'Nouvelle%20Vague'),
#  ('The%20Letdown', 'The%20White%20Tie%20Affair'),
#  ('We%20don%27t%20fit%20in', 'Never%20More%20Than%20Less'),
#  ('I%20Couldn%27t%20Believe%20It%20Was%20True', 'Carla%20Bozulich'),
#  ('A%20Man%20Without%20a%20Country', 'Stinking%20Lizaveta'),
#  ('Darling%20Corey', 'Buell%20Kazee'),
#  ('Sex', '9%20Shocks%20Terror'),
#  ('Bounce%20W/%20WBW', 'Dog%20Vs%20Cat'),
#  ('Show%20Me%20The%20River', 'Eastmountainsouth'),
#  ('Fire%20%26%20Water', '24-7%20Spyz'),
#  ('You%20Can%27t%20Move%20Into%20My%20House', 'Frenzal%20Rhomb'),
#  ('Carheart', 'Virus'),
#  ('Oxygen', 'Swat-Squad'),
#  ('Andropolis', 'Venice%20is%20Sinking'),
#  ('The%20Things%20We%20Did%20Last%20Summer', 'The%20Oscar%20Peterson%20Trio'),
#  ('Conakry', 'Takana%20Zion'),
#  ('Kein%20Wort', 'Breite%20Seite'),
#  ('Jonah%20Joins%20The%20Cab', 'Cab%20Calloway'),
#  ('That%20Was%20Yesterday', 'Charlie%20Shavers'),
#  ('Scarlet%20Winter', 'Fetterline'),
#  ('Over%20the%20Stone%20-%20Concerto%20for%20Harp%3A%20Tros%20y%20Garreg%20%28Over%20the%20Stone%29',
#   'Karl%20Jenkins/Catrin%20Finch/Carmine%20Lauri/London%20Symphony%20Orchestra'),
#  ('Quik%27s%20Groove%20VII', 'DJ%20Quik'),
#  ('L%27Uomo%20Grande', 'Alberto%20Fortis'),
#  ('Telephone%20And%20Rubber%20Band%20%28Live%29%20%282001%20Digital%20Remaster%29',
#   'Penguin%20Caf%C3%A9%20Orchestra'),
#  ('Ghetto%20%28feat.%20Gino%20Green%29', 'J-Kwon'),
#  ('Serenade%20No.%2013%20in%20G_%20%27Eine%20kleine%20Nachtmusik%27%20K525%20%281997%20Digital%20Remaster%29%3A%20III.%20%20Menuetto%20%28Allegretto%29',
#   'Sir%20Neville%20Marriner/Academy%20of%20St%20Martin-in-the-Fields'),
#  ('Decadent', 'The%20Answering%20Machine'),
#  ('The%20AFA%20Song', 'The%20Oppressed'),
#  ('Miles%20Away%20%28In%20the%20style%20of%20%27Madonna%27%29%20%5BWith%20Backing%20Vocals%5D',
#   'Ace%20Karaoke%20Productions'),
#  ('Je%20T%27aime', 'Kolombo'),
#  ('Everything%20I%20Own%20Fits%20In%20This%20Backpack',
#   'The%20Wonder%20Years'),
#  ('Gli%20Amanti%20Di%20Val%20Morel', 'Piccola%20Bottega%20Baltazar'),
#  ('Hace%20Mucho%20Tiempo', 'Los%20Limones'),
#  ('Cosmology', 'Rhian%20Sheehan'),
#  ('Am%20I%20Dead', 'Anti%20Nowhere%20League'),
#  ('schmetterlinge', 'Mutabor'),
#  ('Tres%20Agujas', 'Fito%20Paez'),
#  ('Ataypura%20%28High%20Andes%29', 'Yma%20Sumac'),
#  ('Single', 'Pony%20Club'),
#  ('Outside%20World', 'Sunbeam'),
#  ('Flame%20Fire', 'DYCR'),
#  ('Lie%20To%20Me', 'Brook%20Benton'),
#  ('Dieubouddhallah', 'Les%20Wriggles'),
#  ('The%20Warmth%20Of%20The%20Sun', 'Melissa%20Manchester'),
#  ('The%20Way%20He%20Was%20Raised', 'Josh%20Turner'),
#  ('Subnubus', 'Mouse%20On%20Mars'),
#  ('Long%20Night%20Dreaming', 'Crash%20Parallel'),
#  ('I%20Got%20Love%20If%20You%20Want%20It', 'Slim%20Harpo'),
#  ('Burned%20in%20Blue', 'Glissade'),
#  ('Perpato%20Sta%20Kimata', 'Peggy%20Zina'),
#  ('hoshi-ni-negai-wo', 'To%20Overflow%20Evidence'),
#  ('Goofin%19%20Around', 'Johnny%20Kidd%20And%20The%20Pirates'),
#  ('Feel%20Me', 'Akcent'),
#  ('Denmark', 'Claire%20Hamill'),
#  ('O%20Sonho', 'Madredeus'),
#  ('My%20First%20Guitar', 'Absent%20Elk'),
#  ('Perfect%20World', 'Boyd%20Tinsley'),
#  ('Boring', 'Blink-182'),
#  ('Velvet%20To%20Atone', 'Trader%20Horne'),
#  ('Escapades%20Of%20Pan%20%28Orchestral%20Version%29', 'David%20Lanz'),
#  ('Gotta%20Let%20It%20Go', 'Ms.%20Dynamite'),
#  ('Part%205%3A%20Awaken/Panic/Restraint', 'Peter%20Broderick'),
#  ('Girl%20Trouble%20-%20Original', 'Chris%20Farlowe'),
#  ('Yama%20Yama%20Pretty%20Mama%20%28Digitally%20Remastered%29',
#   'Richard%20Berry'),
#  ('From%20A%20Window', 'Billy%20J.%20Kramer'),
#  ('Down%20The%20Road%20Apiece', 'The%20Count%20Bishops'),
#  ('A%20Short%20Supply%20%28of%20Truth%29', 'Union%2013'),
#  ('Calypso%20Calypso', 'Peter%20Metro'),
#  ('Animal%20House', 'Helix'),
#  ('Power%20Skit%20%232', 'Afu-Ra'),
#  ('Oblige', 'I%20Concur'),
#  ('Voyager', 'Na%C3%A7%C3%A3o%20Zumbi'),
#  ('This%20Love', 'Lou%20Rhodes'),
#  ('Hardcore', 'End%20Of%20Fashion'),
#  ('Somewhere%20Along%20The%20Way%20%28Mono%29%20%281998%20Digital%20Remaster%29',
#   'Cliff%20Richard'),
#  ('Face%20The%20World', 'Nadine%20Sutherland'),
#  ('Morning%20Calls', 'Dashboard%20Confessional'),
#  ('Track', 'Lewis%20Taylor'),
#  ('Jam%20Dodger%20A', 'Wetdog'),
#  ('Give%20It%20Time', 'Middle%20Of%20The%20Road'),
#  ('The%20Body%20Human', 'Robert%20Hood'),
#  ('%28It%20Will%20Have%20To%20Do%29%20Until%20The%20Real%20Thing%20Comes%20Along%20%281995%20Digital%20Remaster%29',
#   'June%20Christy'),
#  ('Give%20Love', 'Tristan%20Garner'),
#  ('Wishing%20Well', 'Black%20Sabbath'),
#  ('What%27s%20A%20Lonely%20Girl%20To%20Do', 'Roger%20Creager'),
#  ('It%20Is%20Familiar', 'Bodies%20Of%20Water'),
#  ('Zid', 'Dino%20Merlin'),
#  ('Bear%20The%20Scars', 'Stampin%C2%B4%20Ground'),
#  ('Gypsy%20Music', 'Luka%20Bloom'),
#  ('All%20Blacks', 'Sebkha-Chott'),
#  ('Casanova%2070%20The%20Secret%20Of%20Cool', 'Air'),
#  ('Hey%20Mr.%20DJ%20%28XFM%20Session%29', 'Tiny%20Masters%20Of%20Today'),
#  ('Sunset%20Coming%20On', 'MALIAN%20MUSICIANS%20%26%20DAMON%20ALBARN'),
#  ('I%20Am%20Your%20Girl%20%28love%20is%20blue%20remix%20by%20A.T%3AF%29',
#   'Neikka%20RPM'),
#  ('Year%20One%20Now', 'Entombed'),
#  ('Electra%20Glide', 'Down%20To%20The%20Bone'),
#  ('Late%20Night%20Saint', 'Nick%20Moss_%20The%20Flip%20Tops'),
#  ('10_000%20Chariots', 'Damian%20%22Jr.%20Gong%22%20Marley'),
#  ('Genie', 'No%20Age'),
#  ('Let%20me%20%28original%29', '2MB'),
#  ('What%27s%20It%20Gonna%20Be', 'Samantha%20Mumba'),
#  ('Drumstern%20%28BONUS%20TRACK%29', 'Marcus%20Worgull'),
#  ('Hump%20In%20Your%20Back', 'Jesse%20Fuller'),
#  ('The%20Promise', 'Deadsoil'),
#  ('Poontang', 'The%20Undisputed%20Truth'),
#  ('Buckeye', 'Johnny%20%26%20the%20Hurricanes'),
#  ('Back%20to%20Basics', 'Rumble%20Pack'),
#  ('Anata%20No%20Kanata', 'Rekka%20Katakiri'),
#  ('Lucy', 'Jealousy'),
#  ('On%20a%20tu%C3%A9%20no%20pourchau', 'Vitor%20Hublot'),
#  ('I%27m%20Glad%20There%20Is%20You', 'The%20Temptations'),
#  ('Scotland%20The%20Brave%20%28Scotland%29',
#   'The%20London%20Theatre%20Orchestra'),
#  ('Lamento%20Borincano', 'Sonora%20Santanera'),
#  ('Would%20A%20Stranger%20Do%3F', 'Roger%20Daltrey'),
#  ('Thank%20You', 'Bebe%20Winans'),
#  ('Giselle', 'Richard%20Galliano'),
#  ('Drunk%20and%20Hot%20Girls', 'Kanye%20West%20/%20Mos%20Def'),
#  ('Gimme_%20Gimme_%20Gimme%20%28Extended%20Version%29', 'yoomiii'),
#  ('Ich%20Lasse%20Mir%20Nichts%20Mehr%20Nehmen', 'Senore%20Matze%20Rossi'),
#  ('Good%20Times', 'Twenty%204%20Seven'),
#  ('Children%20Go%20Where%20I%20Send%20Thee', 'Mandisa'),
#  ('Preacher', 'Diamond%20Rexx'),
#  ('Background%20Of%20Malfunction', 'Flux%20of%20Pink%20Indians'),
#  ('The%20Gun', 'Boss%20Volenti'),
#  ('Knowledge', 'Operation%20Ivy'),
#  ('Savage%20Skulls', 'Padded%20Cell'),
#  ('Fucked%20with%20paranoia', 'Inhume'),
#  ('747%20%28Strangers%20In%20The%20Night%29%20%28Live%20At%20The%20Hammersmith%20Odeon%29%20%281997%20Digital%20Remaster%29',
#   'Saxon'),
#  ('Pop%20That%20Pussy', 'Rebirth%20Brass%20Band_%20Cheeky%20Blakk'),
#  ('Think', 'Judy%20Mowatt'),
#  ('Ablation', 'Commit%20Suicide'),
#  ('Cryin%27', 'Aerosmith'),
#  ('Mambo%20Gumbo', 'Wanderlust'),
#  ('308', 'Ricaine'),
#  ('Victim%20Of%20Love', 'Erasure'),
#  ('Je%20me%20tords', 'Lio'),
#  ('When%20The%20Light%20Is%20Gone%20live%20mix', 'Ubar%20Tmar'),
#  ('Through%20My%20Eyes', 'FFH'),
#  ('Nenphilis', 'The%20Spektrum'),
#  ('Roxy%20Girl', 'The%20Radiators%20%28From%20Space%29'),
#  ('Cops%20And%20Robbers', 'The%20Hoosiers'),
#  ('Una%20paloma%20blanca', 'Diana%20Navarro'),
#  ('Intro', 'Paradise%20Lost'),
#  ('Something%20About%20You', 'Topmodelz'),
#  ('Yesterday%27s%20Headlines', 'Good%20Riddance'),
#  ('Stone%20Turns%20Black', 'Kaya%20Project'),
#  ('Wake%20Me%20Screaming', 'The%20Last%20Dance'),
#  ('1970', 'The%20Exies'),
#  ('Nickindia%20%28remastered%29', 'Nerina%20Pallot'),
#  ('Quiero%20Mas', 'Charanga%2076'),
#  ('Enas%20Apo%20Mas%20%28Anyone%20Of%20Us%20-%20A%20Stupid%20Mistake%29',
#   'Sarbel'),
#  ('Moving%20In%20With%20%28Re-mastered%20version%29', 'Happy%20Mondays'),
#  ('The%20Storm%20%28John%20Dahlback%20Remix%29%20%28Feat.%20Cozi%29',
#   'Jerry%20Ropero%20Featuring%20Cozi'),
#  ('Ebb%20And%20Flow', 'Jenniffer%20Kae'),
#  ('Bones', 'Claw%20Boys%20Claw'),
#  ('Happy', 'Liam%20Lynch'),
#  ('Han%20Yan%20Cui', 'Sally%20Yeh'),
#  ('Danse%20Macabre', 'Minnesota%20Orchestra'),
#  ('No%20Sympathy', 'The%20Wailers'),
#  ('Till%20Ya%20Drop%21%202007', 'DJ%20Remy'),
#  ('After%20Sunset%202009', 'Veselin%20Tasev'),
#  ('Eu%20N%C3%A3o%20Sou%20Da%20Sua%20Rua', 'Arnaldo%20Antunes'),
#  ('Tom%20Dooley', 'Kari%20Tapio'),
#  ('Tv%C3%A5%20av%20Oss', 'Attack'),
#  ('Shiver%20The%20Trees', 'Attic%20Lights'),
#  ('Woman%20In%20White%20%28LIVE%29', '220%20Volt'),
#  ('Devoted', 'Slowpho'),
#  ('Amerika%20%28Live%20Verison%29', 'Jaco%20Pastorius%20Big%20Band'),
#  ('Until%20The%20Day%20I%20Die%20%28Album%20Version%29',
#   'Story%20Of%20The%20Year'),
#  ('Shine%20On', 'The%20Untouchables'),
#  ('Rubina%27s%20Blue%20Sky%20Of%20Happiness', 'Joe%20Satriani'),
#  ('Still...You%20Turn%20Me%20On', 'Emerson_%20Lake%20%26%20Palmer'),
#  ('Los%20barrios%20de%20Santiago', 'Los%20Compadres'),
#  ('Love%20Appetite', 'Steve%20Cropper%20%26%20Felix%20Cavaliere'),
#  ('I', '%C3%85rabrot'),
#  ('Holdin%27%20On%20To%20Yesterday', 'Ambrosia'),
#  ('Latin%20-%20Phone%20Message', 'Andrew%20Gold'),
#  ('The%20Man%20Without%20A%20Name', 'I%20Walk%20The%20Line'),
#  ('The%20Playhouse%20Saint', 'Ed%20McCurdy'),
#  ('Between%20Tholozan%20And%20Oleatha', 'Grand%20Ulena'),
#  ('House%20Of%20Broken%20Dreams', 'Crosby_%20Stills%20%26%20Nash'),
#  ('Moose%20On%20The%20Loose', 'Vicious%20Rumours'),
#  ('Nuns%20Leg', 'Shit%20and%20Shine'),
#  ('Poppin%20Wit%20Game', 'Assassin'),
#  ('Sons%20Of%20Sarah%20Connors', 'Megalon'),
#  ('My%20Moves%20Are%20White%20%5BWhite%20Hot_%20That%20Is%5D%20%28Album%20Version%29',
#   'Cobra%20Starship'),
#  ('Open%20Arms%20Monkey%20Business%20Club%20Mix', 'Liquid%20Spill'),
#  ('Hymn', 'Cabballero'),
#  ('Rewind%20%28Demo%29', 'Paramore'),
#  ('Alo%20Fevereiro', 'Doris%20Monteiro'),
#  ('Labels%20Of%20Blues', 'Shotgun%20Honeymoon'),
#  ('This%20Cocaine%20Makes%20Me%20Feel%20Like%20I%27m%20On%20This%20Song',
#   'System%20of%20a%20Down'),
#  ('The%20Real%20Me%20featuring%20Ria%20Currie', 'Speedometer'),
#  ('Sew%20My%20Name', 'Josh%20Pyke'),
#  ('Give%20Thanks%20and%20Praise%20-%20Original', 'Barry%20Brown'),
#  ('Sailing%20To%20The%20Botton', 'Williamson'),
#  ('The%20Blues%20Ain%27t%20Nothin%27', 'The%20Dickey%20Betts%20Band'),
#  ('Entrapment', 'Naked%20Raygun'),
#  ('Kaizers%20115.%20Dr%C3%B8m', 'Kaizers%20Orchestra'),
#  ('Callin%27%20Heaven', 'Arthur%20Adams'),
#  ('Jesus%20Christ', 'Wesley%20Willis'),
#  ('Hungry%20Belly', 'Manjul'),
#  ('Sauver%20L%27Amour', 'Daniel%20Balavoine'),
#  ('Don%C2%B4t%20Let%20It%20Bring%20You%20Down', 'Sandhy%20SonDoro'),
#  ('Tell%20Me%20Mama', 'Willie%20%22Big%20Eyes%22%20Smith'),
#  ('Bucket%20Of%20Crawfish', 'Loco%20Zydeco'),
#  ('Rock-Legenden', 'Planlos'),
#  ('Fuersattel', 'Boozoo%20Bajou'),
#  ('Thirteen', 'Not%20Your%20Average%20Hippy'),
#  ('Moonlight', 'Dreams%20Come%20True'),
#  ('I%20Believe%20In%20You%20%281997%20Digital%20Remaster%29', 'Talk%20Talk'),
#  ('The%20Way%20I%20See%20%2893bpm%29', 'Domu%20presents%20Pete%20Simpson'),
#  ('Ambivalent', 'Dominik%20Eulberg'),
#  ('Major%20Happy%27s%20Up%20And%20Coming%20Once%20Upon%20A%20Good%20Time%20Band',
#   'The%20Rutles'),
#  ('Movin%27%20On%20Up', 'Half%20Japanese'),
#  ('Sonata%20In%20A%20Major%20Op.%20120%20D%20664%3A%20I.%20Allegro%20Moderato%20%28Schubert%29',
#   'Massimiliano%20Damerini'),
#  ('Undercurrent%20%28Alucidnation%20Downtempo%20Mix%29', 'Fragile%20State'),
#  ('I%20Wish%20I%20Knew', 'John%20Coltrane%20Quartet'),
#  ('Masse', 'Niederflur'),
#  ('Uncle%20Darrow%27s', 'Jeff%20Lorber'),
#  ('Body%20And%20Fender%20Man', 'Microwave%20Dave%20and%20the%20Nukes'),
#  ('Gemini%20%28Birthday%20Song%29', 'Why%3F'),
#  ('Sax%20Boogie', 'Cantovano%20and%20His%20Orchestra'),
#  ('It%20Won%27t%20Escape%20Those%20Lips', 'Venice'),
#  ('Coming%20Home', 'Eric%20Sneo'),
#  ('hug%20acoustic%20version', 'T-Bone'),
#  ('After%20dark', 'AGATHODAIMON'),
#  ('Karlovy%20Vary', 'Bratri%20Ebenove'),
#  ('Never%20Comin%27%20Home', 'Halfway%20to%20Gone'),
#  ('Rewind', 'Chiasm'),
#  ('Nadie%20Me%20quiere', 'Los%20Enemigos'),
#  ('Cuando%20Te%20Hablen%20De%20Mi', 'La%20Habitacion%20Roja'),
#  ('Job', 'Patent%20Pending'),
#  ('Somebody%20Loves%20Me', 'Kate%20Smith'),
#  ('Take%20Your%20Time%20Rag', 'Furry%20Lewis'),
#  ('D.D.T.%20Fin%2013', 'Halo%20Of%20Flies'),
#  ('Me%20Name%20Tiger%20-%20Original', 'Tiger'),
#  ('Sailing%20Keeps%20You%20Safe', 'Shooting%20At%20Unarmed%20Men'),
#  ('Broken%20Arrows', 'Rabbit'),
#  ('I%20Can%27t%20Stand%20Losing%20You', 'Curtis%20Stigers'),
#  ('The%20Clockwise%20Witness', 'Devotchka'),
#  ('Celebrate%20the%20Summer%202006', 'Lacuna'),
#  ('J%C3%A4lleen%20on%20meid%C3%A4n', 'Haikara'),
#  ('Ain%27t%20Got%20Time%20To%20Waste', 'Bullet'),
#  ('Chapter%207%3A%20Every%20Round%20With%20God%20Goes%20Higher',
#   'Smokie%20Norful'),
#  ('Circles', 'Kreidler'),
#  ('Cocha%20Meu%20Minino', 'Heredeiros%20Da%20Crus'),
#  ('Don%27t%20Sleep',
#   'Audio%20Soul%20Project%20feat.%20Nathan%20Drew%20Larsen'),
#  ('Going%20Back%20To%20Louisiana', 'Carey%20Bell'),
#  ('Big%20%20Ass%20Green%20Van', 'Bill%20Perry'),
#  ('Jesus%20Is%20Coming', 'Watchmaker'),
#  ('Cafezinho', 'Bob%20Baldwin'),
#  ('Never%20Knew%20Love', 'Rick%20Astley'),
#  ('Mississippi%20Delta', 'Bobbie%20Gentry'),
#  ('V%C3%A5gorna', 'Patrik%20Isaksson'),
#  ('Prayee', 'The%20Chantels'),
#  ('Hideaway%20%28Album%20Version%29', 'David%20Sanborn'),
#  ('Red%20Apples', 'Kurt%20Vile'),
#  ('Assembly%20Line', 'Steve%20Morse'),
#  ('Lord%20Of%20Lies', 'A.C.T'),
#  ('La%20Mosca', 'Impact'),
#  ('La%20Mujer%20Del%20Torero', 'Rocio%20Jurado'),
#  ('Malancolo', 'Conjunto%20Clasico'),
#  ('Forgotten%20Lives', 'Eastern%20Star'),
#  ('Shi%20Yi', 'Valen%20Hsu'),
#  ('Just%20a%20Dream', 'Billy%20Boy%20Arnold'),
#  ('Antartica', 'Asia%202001'),
#  ('Venus', 'Gloria%20Lasso'),
#  ('Your%20Ma%20Said%20You%20Cried%20In%20Your%20Sleep%20Last%20Night%20%20%282006%20Remastered%20LP%20Version%29',
#   'Robert%20Plant'),
#  ('No%20Easy%20Way%20Out', 'DJ%20Fait'),
#  ('Start', 'Omni'),
#  ('All%20Night%20Long', 'Muddy%20Waters'),
#  ('Sandhurst%20In%20Zero%20G', 'Senser'),
#  ('Iron%20Butterfly%20Theme', 'Iron%20Butterfly'),
#  ('Cancerboy%20on%20Hash', 'DD/MM/YYYY'),
#  ('Vallejo', 'Miracle%20Chosuke'),
#  ('It%27s%20A%20Blessing', 'The%20Jackson%20Southernaires'),
#  ('Help%20Me%20to%20Understand', 'Johnny%20Jenkins'),
#  ('Never%20Seen%20The%20Light%20Of%20Day%20%28Radio%20Edit%29',
#   'Mando%20Diao'),
#  ('The%20Bubble%20Effect', 'Scienz%20of%20Life'),
#  ('Dig%20It', 'Pirupa_%20Pigi'),
#  ('Undulation', 'Riow%20Arai'),
#  ('So%20Alone', 'David%20T.%20Chastain'),
#  ('Believe%20Yourself%20%28Album%20Version%29', 'One%20Way%20System'),
#  ('First%20Love', 'C-Block'),
#  ('Make%20Me%20Feel', 'Benassi%20Bros.%20Feat.%20Dhany'),
#  ('Como%20Eu%20Queria', 'Tihuana'),
#  ('La%20Verdadera%20Libertad', 'Andres%20Calamaro'),
#  ('Valiums%20A%20Tu%20Tia', 'Los%20Amantes%20De%20Lola'),
#  ('Merciless%20tyranny', 'Incantation'),
#  ('Dialogue', 'The%20Clancy%20Brothers%20With%20Tommy%20Makem'),
#  ('God%20Only%20Knows', 'Rockabye%20Baby%21'),
#  ('The%20Art%20Of%20Parties', 'Japan'),
#  ('It%20Keep%20Rainin%27%20%28Tears%20From%20My%20Eyes%29%20%28Radio%20Edit%29',
#   'Bitty%20McLean'),
#  ('Tomorrow%27s%20Gonna%20Be', 'Continental%20Drifters'),
#  ('Invisible', 'Enchant'),
#  ('Benedito', 'AfroReggae'),
#  ('I%20Wish%20We%27d%20All%20Been%20Ready%20%28Key-Ab-Premiere%20Performance%20Plus%29',
#   'DC%20Talk'),
#  ('Soul%20Power', 'Kokolo'),
#  ('Oh%20Take%20Me%20Back',
#   'Charlie%20Haden%20/%20Tanya%20Haden%20/%20Rachel%20Haden'),
#  ('Cuanta%20Vida%20WLopez%20%26%20D%20Ferrero%20House%20Remix', 'Pastora'),
#  ('New%20Boys', 'The%20Adverts'),
#  ('Fan%20Mail', 'The%20Dickies'),
#  ('Linha%20Vermelha', 'O%20Rappa'),
#  ('Rowdy', 'Clint%20Eastwood'),
#  ('Mamma%20Voglio%20Anch%27io%20La%20Fidanzata', 'Natalino%20Otto'),
#  ('Rimes%20Instinctives', 'Nessbeal'),
#  ('Liisborg%20Error', 'Feadz'),
#  ('Get%20Off%20The%20Stage', 'Normie%20Rowe'),
#  ('C.e.b.%20%28Album%20Version%29', 'No%20Innocent%20Victim'),
#  ('Warn%20Them%20Jah%20Dub', 'Yabby%20You'),
#  ('Shelter%20In%20The%20Storm%20%28Album%20Version%29',
#   'James%20Newton%20Howard/The%20Postman%20Soundtrack'),
#  ('I%20Love%20You%20Haters', 'Kaze'),
#  ('You%20Don%27t%20Know%20What%20Love%20Is%20%28You%20Just%20Do%20As%20You%27re%20Told%29',
#   'Daniel%20Merriweather'),
#  ('Take%20Me%20To%20The%20River', 'Exile'),
#  ('Let%20it%20Go', 'Bernard%20Harris'),
#  ('Into%20The%20Floyd', 'Chad%20Smith%27s%20Bombastic%20Meatbats'),
#  ('Jet%20set', 'Los%20Manolos'),
#  ('I%20Believe%20In%20Miracles', 'Sunlightsquare'),
#  ('Honey%20Pie', 'Bill%20Perry'),
#  ('Elefante', 'Verdena'),
#  ('Intro%20%28grooveman%20Spot%20Remix%29', 'DJ%20Mitsu%20The%20Beats'),
#  ('Chasing%20The%20Sunrise', 'Luke%20Terry'),
#  ('Young%20Girl', 'Edi%20Fitzroy'),
#  ('Bookie%20Blues', 'Count%20Basie%20Big%20Band'),
#  ('Mudslide', 'The%20Bluetones'),
#  ('Sketch%20For%20Dawn%20%28Live%2013.8.1981%29', 'The%20Durutti%20Column'),
#  ('Io%20Vado%20Con%20L%27Anima', 'Gino%20Paoli'),
#  ('New%20Frontiers', 'Aural%20Float'),
#  ('I%20Go%20-%20Live%20At%20The%20BBC%20%5B31/5/66%5D', 'Billy%20Fury'),
#  ('Like%20Sunshine', 'Heston'),
#  ('It%27s%20A%20Trip%20%28Stems%20Mix%29', 'Shakespears%20Sister'),
#  ('Un%20Abecedario%20Sin%20Letras', 'Platero%20Y%20Tu'),
#  ('Dirty%20Disco%20II%20%28Pre-Mix%20version%29', 'Section%2025'),
#  ('Attention%20Cherie', 'April%20March'),
#  ('Don%27t%20You%20%28Forget%20About%20Me%29%20%28Album%20Version%29',
#   'Life%20Of%20Agony'),
#  ('Until%20Now', 'Adema'),
#  ('Zanzibar',
#   'Ed%C3%BA%20Lobo%20/%20Airto%20Moreira%20/%20Hermeto%20Pascoal%20/%20Claudio%20Slow%20/%20Jose%20Mariono'),
#  ('Heroes%20Get%20Remembered_%20Legends%20Never%20Die',
#   'Four%20Year%20Strong'),
#  ('Abre%20los%20ojos', 'Mala%20Reputaci%C3%B3n'),
#  ('Everyday%20I%20Have%20The%20Blues', 'Lightnin%27%20Hopkins'),
#  ('Tamarack%20Pines', 'George%20Winston'),
#  ('Everybody%20Loves%20You%20Now', 'The%20Hassles%20Feat.%20Billy%20Joel'),
#  ('A%20Touch%20Of%20Paradise', 'Beady%20Belle'),
#  ('He%27s%20Pulling%20His%20Whiskers%20On', 'Hot%20Lips%20Page'),
#  ('I%27ve%20Been%20Waiting', 'Anthony%20Cruz'),
#  ('She%20Wishes%20I%20Were%20You', 'Terry%20Stafford'),
#  ('Cadillac%20Solitario%20%28Rockdelux%20Experience%2023/11/04%29',
#   'Loquillo'),
#  ('Superstring', 'Kain%20van%20Stone'),
#  ('Out%20Of%20My%20Mind', 'John%20Mayer'),
#  ('Thrasher', 'Evile'),
#  ('All%20I%20Can%27t%20Explain', 'Mae%20Moore'),
#  ('EYE%20OF%20THE%20STORM', 'HEATHEN'),
#  ('Already%20Died', 'Eagles%20Of%20Death%20Metal'),
#  ('Rambel%20In%20De%20Jangel', 'Basti%20Grub'),
#  ('Abusus%20Dasein%2012', 'Stendal%20Blast'),
#  ('Solo%20Te%20Llame', 'Plan%20B'),
#  ('You%20Were%20Alone', 'Casiotone%20For%20The%20Painfully%20Alone'),
#  ('Like%20You%20%28Supermayer%20Mix%29', 'Gui%20Boratto'),
#  ('Save%20The%20World', 'Mick%20Clarke'),
#  ('La%20Princesa%20De%20Mis%20Sue%C3%B1os%20%28Octeto%20Versi%C3%B3n%29',
#   'Obk'),
#  ('Intro', 'H.e.a.t'),
#  ('Talk%20Show', 'Andy%20Stochansky'),
#  ('California%20%28Live%29', 'Hadag%20Nahash'),
#  ('Tomorrow%20%28Live%20Version%29', 'The%20Durutti%20Column'),
#  ('Little%20Paradise', 'Pat%20Benatar'),
#  ('Bodyfly%20%28Conrado%20Martinez%20Remix%29',
#   'Dynamix%20Featuring%20Inda%20Matrix'),
#  ('Push%20the%20Right%20Knob', 'Bastian'),
#  ('The%20Change%20Came%20Suddenly', 'A%20Life%20Once%20Lost'),
#  ('Palace%20Of%20My%20Soul', 'Lispector'),
#  ('Tim%20Dom%20Dom', 'Jorge%20Ben'),
#  ('Kolmatta%20linjaa%20takaisin%20%20-Beautiful%20in%20the%20Rain-', 'Fredi'),
#  ('Love%20For%20Sale', 'Marvin%20Gaye'),
#  ('Prologue%20%28Little%20Shop%20Of%20Horrors%29',
#   'Michelle%20Weeks%20/%20Tichina%20Arnold%20/%20Tisha%20Campbell%20/%20Bill%20Mitchell'),
#  ('The%20Level', 'Sun%20Eats%20Hours'),
#  ('La%20tua%20fretta', 'Verdena'),
#  ('Weh%20the%20Love%20Gone', 'Natty%20King'),
#  ('East%20To%20West', 'Anti-Pasti'),
#  ('Luodinkest%C3%A4v%C3%A4%20poikayst%C3%A4v%C3%A4',
#   'Kimmo%20Liskom%C3%A4en%20Pitk%C3%A4t%20Kalsarit'),
#  ('Naa%20Puchna', 'Malkit%20Singh'),
#  ('Send%20Me%20On%20My%20Way%20%28Album%20Version%29', 'Rusted%20Root'),
#  ('W.L.T.M.', 'Jimmy%20Nail'),
#  ('Nordlandsbilleder%20%28Pictures%20from%20Nordland%29%20Suite%20No.%201%20Op.%205%3A%20I.%20%20%20%20%20%20%20Kvinneprofill%20%28Portrait%20of%20a%20woman%29',
#   'Leif%20Ove%20Andsnes'),
#  ('No%20Place%20To%20Run%20%28Live%20In%20Hammersmith%20%27BBC%20In%20Concert%27%29',
#   'UFO'),
#  ('Don%27t%20Blame%20Me', 'Timi%20Yuro'),
#  ('Lei%20M%27Ama', 'I%20Ribelli'),
#  ('Back%20Home', 'Joe%20Smooth'),
#  ('14%20Valses/Waltzes%20%282005%20Digital%20Remaster%29%3A%20No.6%20in%20D%20flat%20Op.64%20No.1',
#   'Dinu%20Lipatti'),
#  ('Gun', 'Soundgarden'),
#  ('Rosary%20Job%20%28Demo%29%20%28Album%29', 'Vaselines'),
#  ('When%20Something%20Old%20Dies', 'Kingston%20Wall'),
#  ('Feel%20The%20Heat%202000', 'Masterboy'),
#  ('Track%20%26%20Field', 'Demarkus%20Lewis'),
#  ('Love%20Don%27t%20Go%20Through%20No%20Changes%20On%20Me', 'Sister%20Sledge'),
#  ('You%20Are', 'Fat%20Jon'),
#  ('Falsified', 'Miles%20Hunt'),
#  ('Third%20Marie_%20The%20%20%28The%20Right%20Amount%20Album%20Version%29',
#   'Bon%20Voyage'),
#  ('Cheche', 'Patrick%20Saint-Eloi'),
#  ('Sodom%20%26%20Gomorrah', 'The%20Twinkle%20Brothers'),
#  ('Ode%20til%20Arne%20Nordheim%20%28I-III%29', 'Jono%20El%20Grande'),
#  ('Big%20Brat', 'Phantom%20Planet'),
#  ('The%20Love%20I%20Never%20Had', 'The%20Monsters'),
#  ('Alguien%20La%20Vi%C3%B3%20Partir', 'Diego%20Torres'),
#  ('Forgiven', 'The%20Space%20Brothers'),
#  ('Outra%20Rezada%20Do%20Pinto%20D%27Herb%C3%B2n', 'Ruxe%20Ruxe'),
#  ('If%27n%20Myself%20To%20Death', 'Joe%20King%20Carrasco'),
#  ('Du%20Sommeil_%20du%20Soleil_%20de%20l%27Oseille', 'La%20Rumeur'),
#  ('Put%20Your%20Drink%20Down%20%5BOriginal%5D', 'Mr.%20V'),
#  ('Jack%20O%27Diamonds%20/%20Merrily%20Kiss%20The%20Quaker',
#   'Robin%20Bullock'),
#  ('The%20Deep%20Project', 'Filter'),
#  ('Salsanova', 'Johnny%20Fiasco'),
#  ('If%20You%20Tolerate%20This', 'Eric%20Chase'),
#  ('One%20Bedroom%20Apartment', 'Clann%20Zu'),
#  ('Te%20olvidar%C3%A1s%20de%20m%C3%AD', 'QBO'),
#  ('Talkin%27%20that%20Talk', 'The%20Jive%20Turkeys'),
#  ('tides%20that%20kill', 'Panzer%20AG'),
#  ('Double%20the%20Dose', 'Go%20Drowsy'),
#  ('Didnt%20Feel%20No%20Pain', 'Nicole%20Willis'),
#  ('Cold%20War', 'The%20Morning%20Benders'),
#  ('Raga%20-%20Shuddha%20Sarang_%20Aalap', 'Bhimsen%20Joshi'),
#  ('Single%20Second', 'More%20Than%20Crossed'),
#  ('I%20Want%20To%20Hear%20It%20From%20You', 'Go%20West'),
#  ('Unseen%20World%20%5BExplicit%5D', 'Mad%20Skillz'),
#  ('String%20Quartet%20No.12%20in%20E%20flat%20major%20Op.127%20%3A%20III%20Scherzo%20%28Vivace%29',
#   'Endellion%20String%20Quartet'),
#  ('Attitude%20%28Nobody%20But%20Me%29', 'Robert%20Moore'),
#  ('Rehabilitacja%20Komunist%C3%B3w', 'Jacek%20Kaczmarski'),
#  ('Sucker%204U', 'Wealthy%20Beggar'),
#  ('Familiar%20Places', 'Winter%20Hours'),
#  ('%28So%20schn%C3%B6%20kaust%20gor%20net%29%20schaun', 'Texta'),
#  ('Come%20To%20The%20Bower', 'Shane%20MacGowan%20And%20The%20Popes'),
#  ('Beatitude', 'Duderstadt%20%26%20Kirsty%20Hawkshaw'),
#  ('Com%20Portugal%20No%20Cora%C3%A7%C3%A3o', 'Fernando%20Correia%20Marques'),
#  ('Mystery%20Trip%20%28Original%20Mix%29', 'Auditory%20Canvas'),
#  ('El%20Viejo%20Del%20Sombreron', 'La%20Sonora%20Dinamita'),
#  ('The%20First%20Queer%20Santy%20Claus%20%28Album%20Version%29',
#   'Larry%20The%20Cable%20Guy'),
#  ('Big%20Town', 'Roy%20Brown'),
#  ('Blown%20Away', 'The%20Violet%20Burning'),
#  ('Sing%20Their%20Souls%20Back%20Home', 'Billy%20Bragg'),
#  ('In%20Search%20Of%20My%20Heart', 'Roseanna%20Vitro'),
#  ('Mozambique', 'Richard%20Galliano'),
#  ('Love%20Don%27t%20Live%20Here%20Anymore', 'Jimmy%20Nail'),
#  ('Special%20Agent%20%28Railroad%20Police%20Blues%29',
#   'Sleepy%20John%20Estes'),
#  ('Triste%20Tropique%20%28feat.%20Olodum%20%26%20Edy%20Vox%29',
#   'Rockin%27%20Squat'),
#  ('Just%20Barely%20Famous', 'Herb%20Eimerman'),
#  ('Nothing%20Touches%20Me%20%28BBC%20Radio%201%20Evening%20Session%29',
#   'Radiohead'),
#  ('Sugar%20Babe', 'Buster%20Brown'),
#  ('An%20Sagairtin', 'Joe%20Heaney'),
#  ('E%27she%27no%20%28World%29', 'R.%20Carlos%20Nakai'),
#  ('Bone%20And%20Flesh', 'Tony%20Levin'),
#  ('Hora%20de%20cambiar', 'Play'),
#  ('Journey%20Stages', 'Yespiring'),
#  ('Doctor%20Clayton%20Blues', 'Doctor%20%28Peter%29%20Clayton'),
#  ('You%27re%20Always%20Near', 'The%20Alarm%20Clocks'),
#  ('Me%20He%20Acostrumbrado%28Con%20NS%29', 'Magnatiz'),
#  ('Help%20Is%20On%20Its%20Way', 'Little%20River%20Band'),
#  ('Salt%20%26%20Velvet', 'Brainbox'),
#  ('D%C3%A9cembre', 'Pauline%20Croze'),
#  ('Fever', 'Dee%20Clark'),
#  ('Adagio%20Espressivo', 'Epos'),
#  ('I%20Need%20Terry%20Sheridan', 'Alan%20Silvestri'),
#  ('Formiche', 'Lucio%20Battisti'),
#  ('I%27m%20So%20Bad%20%2810%22%20EP%29', 'Oingo%20Boingo'),
#  ('Atoll%20%28Laurentian%27s%29', '%2AShels'),
#  ('Lost%20In%20A%20Feeling%20%28LP%20Version%29', 'Claudia%20Church'),
#  ('Play%20To%20Win%20%2812%27%27%20Extended%20Version%29', 'Heaven%2017'),
#  ('It%27s%20Time', 'Mara%20Carlyle'),
#  ('Beautiful', 'Jonah33'),
#  ('Eastbourne%20Lights', 'Darren%20Hayman'),
#  ('Got%20It%20Wrong', 'Wakey%21Wakey%21'),
#  ('Runaway%20%28Ford%20Remix%20Radio%20Edit%29', 'iio'),
#  ('Round%20The%20Bays%20Pt.%201', 'Confucius'),
#  ('A%20Different%20World', 'Ashley%20Walters'),
#  ('Islands%20%28LP%20Version%29', 'Danny%20O%27Keefe'),
#  ('4%25%20Pantomime%20%282000%20Digital%20Remaster%29', 'The%20Band'),
#  ('Chicken%20%28Live%29', 'Mississippi%20John%20Hurt'),
#  ('Dead%20%2B%20Rural%20%28Album%29', 'Handsome%20Furs'),
#  ('Empego%20Naroco', 'Tito%20Rodriguez'),
#  ('Concerto%20No%201%20In%20B%20Flat%20Minor_%20Op23%3A%20Second%20Movement%20-%20Andante%20Semplice%3B%20Prestissimo%3B%20Tempo%20Primo',
#   'Van%20Cliburn'),
#  ('Kicked%20Out%20The%20Club',
#   'Mistah%20F.A.B%20ft.E40_%20%20Mac%20Dre_%20Messy%20Marv_%20Yukmouth_%20Mac%20Mall_%20Mr.%20Kee_%20Various%20Otheres'),
#  ('The%20Solo%20To%20Untamed%20Place', 'Ametsub'),
#  ('In%20The%20Presence%20Of%20Angels', 'Gandalf'),
#  ('Private%20Room%20Intro', 'Avant'),
#  ('Black%20Angel%20%28Album%20mix%29', 'Mind%3AState'),
#  ('Passages', 'Kevin%20Kern'),
#  ('Green%20Love', 'Hilt'),
#  ('Roda%20Piao%20%28Spiritual%20South%20Remix%29', 'Azymuth'),
#  ('Citizenihilist', 'Trap%20Them'),
#  ('Stop%20This%20Game', 'Cheap%20Trick'),
#  ('Flight', 'Johnny%20Thunders%20%26%20The%20Heartbreakers'),
#  ('The%20Scamp', 'Reginald%20R.%20Robinson'),
#  ('Tamagnoko', 'Issa%20Bagayogo'),
#  ('I%20Wanna%20Hold%20Your%20Hand',
#   'The%20Boxmasters%20feat.%20Billy%20Bob%20Thornton'),
#  ('All%20That%20I%20Need', 'Blind%20Melon'),
#  ('The%20One', 'Udo'),
#  ('Digital%20Complexion', 'Dean%20Fichna'),
#  ('Homemade%20%28Live%20Version%29', 'Nicole%20C.%20Mullen'),
#  ('What%20In%20The%20World%20%28Album%20Version%29', 'Babbie%20Mason'),
#  ('Curfew', 'Fyah%20Blaze'),
#  ('Abbracciami%20Pi%C3%B9%20Forte', 'Angelo%20dei%20Teppisti%20dei%20Sogni'),
#  ('What%27s%20Happenin%27%20Sun', 'Sir%20Mix-A-Lot'),
#  ('LaLa%20Land', 'Wallis%20Bird'),
#  ('Try', 'Tree'),
#  ('Some%20Dumb%20Girl', 'Anjulie'),
#  ('Ghost%20train', 'The%20Sharks'),
#  ('Jetlag', 'Mr.Phillips'),
#  ('Conversaciones', 'Braille'),
#  ('Penpals', 'Roll%20Deep'),
#  ('Selah', 'Lauryn%20Hill'),
#  ('Over%20The%20Weekend', 'Nick%20Heyward'),
#  ('Pour%20Jane%20%28live%29', 'Cali'),
#  ('Dancing%20In%20The%20Dark', 'Micky%20Modelle%20v%20Jessy'),
#  ('As%20I%20Slither', 'KATAKLYSM'),
#  ('Thoughts%20Pay%20No%20Toll', 'No%20Name'),
#  ('Don%27t%20Upset%20The%20Rhythm%20%28Go%20Baby%20Go%29', 'Noisettes'),
#  ('Secret', 'DJ%20Sakin%20vs.%20weimaR'),
#  ('Not%20My%20Love', 'Tides%20Of%20Man'),
#  ('Barrag%C3%A1n', 'Kamelo%20Punto%20Semos'),
#  ('Amo%20Que%20Me%20Odien', 'Mr.%20Shadow_%20Se%C3%B1or%20Sombra'),
#  ('Still', 'Foo%20Fighters'),
#  ('Lo%20Mismo%20Blues', 'Henry%20Kaiser'),
#  ('Time%20Waits%20For%20No%20One', 'Silhouette%20Brown'),
#  ('Bread', 'John%20Brown%5C%27s%20Body'),
#  ('Dreams%20of%20life', 'Molly%20Hatchet'),
#  ('Anthology%3A%20A%20Tribute%20to%20Music', 'Scienz%20of%20Life'),
#  ('Mission%20Complete%20%28feat.%20TayDaTay_%20E-Sick%20%26%20Hennessy%29',
#   'Dush%20Tray'),
#  ('Parasite', 'The%20Souljazz%20Orchestra'),
#  ('Tha%20Me%20Dis', 'Irini%20Merkouri'),
#  ('The%20Atlantic%20Ocean', 'Richard%20Swift'),
#  ('Grunnsteinar', 'Arve%20Henriksen%20%26%20Elling%20Vanberg'),
#  ('George%20Bush', 'Mother%20Gong'),
#  ('Eu%20Tenho%20Um%20Fraquinho%20Por%20Ti', 'Fausto'),
#  ('Bad%20Bad%20Baby', 'Natural%20Born%20Grooves%20feat.%20Thea%20Austin'),
#  ('Radishes', 'Hurl'),
#  ('Mama%20Look%20Deh%20%28Album%29', 'The%20Reggae%20Boys'),
#  ('Pocket%20Full%20of%20Stones', 'UGK%20%28Underground%20Kingz%29'),
#  ('Warrior', 'Matisyahu'),
#  ('Old%20Man%20Willis%20%28Single%20Version%29%20%28Bonus%20Track%29',
#   'Tony%20Joe%20White'),
#  ('Heartstopper', 'Emiliana%20Torrini'),
#  ('Forever', 'Mikael%20Stav%C3%B6strand%20%26%20Franco%20Cinelli'),
#  ('Meat%20Wagon', 'The%20Haunted'),
#  ('Energy%20Vibrations', 'Johnny%20Pearson'),
#  ('Trouble%20And%20Pain', 'The%20Robert%20Cray%20Band'),
#  ('Lift%20My%20Burdens', 'Naomi%20Shelton%20%26%20the%20Gospel%20Queens'),
#  ('The%20Glory%20Of%20Love', 'Five%20Keys'),
#  ('Running%20And%20Hiding', 'Sunshaker'),
#  ('Right%20Reverend', 'Leatherface'),
#  ('Act%20Right', 'Wynona%20Carr'),
#  ('Bella%20Bella', 'Ravel'),
#  ('Light%20Reborn', 'AGATHODAIMON'),
#  ('Lodge', 'Bounty%20Killer'),
#  ('The%20Utilitarian%20Christmas%20Jingle',
#   'Lullaby%20For%20The%20Working%20Class'),
#  ('Watch%20Us%20Touch', 'The%20Creators%20feat.%20Consequence'),
#  ('Colpo%20Di%20Specchio', 'Marco%20Parente'),
#  ('Southern%20Casey%20Jones', 'Jesse%20James'),
#  ('Love%20Machine', 'Coco%20Electrik'),
#  ('Outro%20%28Amended%20Version%29', 'Busta%20Rhymes'),
#  ('You%27re%20The%20Best', 'Keni%20Burke'),
#  ('Live', 'The%20Badloves'),
#  ('Haul%20%26%20Pull%20%28Bobby%20Konders%20Remix%29', 'Daddy%20Freddy'),
#  ('Giz%20Starts%20Buggin%27%20%28LP%20Version%29', 'Audio%20Two'),
#  ('All%20I%20Have%20To%20Offer%20You%20Is%20Me',
#   'Mac%20Wiseman%20%28With%20Special%20Guests%20Lester%20Flatt%20%26%20Chubby%20Wise%29'),
#  ('DEADLY%20PLAYER', 'Loudness'),
#  ('Convicting%20The%20Squirrel%20%28Album%29', 'Hugh%20Hopper'),
#  ('Invitation%20To%20the%20Blues', 'Undertakin%27%20Daddies'),
#  ('Shape-Eisha', 'Shaka%20Shamba'),
#  ('Jeepers%20Creepers', 'Louis%20Armstrong'),
#  ('pure%20tension', 'Panzer%20AG'),
#  ('Oh_%20How%20It%20Hurts', 'Barbara%20Mason'),
#  ('Seagull%20%28The%20West%20Coast%20Oil%20Tragedy%20Of%20%2768%29%20%281999%20Digital%20Remaster%29',
#   'Love%20Sculpture'),
#  ('The%20Clap', 'Steve%20Morse'),
#  ('In%20The%20Shadows', 'The%20Stranglers'),
#  ('Chipoti%20chipota', 'Les%20Hurlements%20D%27leo'),
#  ('Withered%20On%20The%20Vine', 'Nick%20Lowe'),
#  ('Vulture%20Kisses', 'SO%20SO%20Modern'),
#  ('M%C3%A9moire%20de%20singes', 'LOFOFORA'),
#  ('Summer%20Breezin%27', 'George%20Duke'),
#  ('Paz%20En%20Este%20Amor%20%28Paz%20Na%20Cama%29', 'Ana%20Gabriel'),
#  ('Don%27t%20Come%20My%20Way', '220%20Volt'),
#  ('My%20Favorite%20Things', 'Opa%20Cupa'),
#  ('Future%20King', 'Zero%20Le%20Cr%C3%AAche'),
#  ('Memories%20%28Someone%20We%27ll%20Never%20Know%29', 'Clint%20Mansell'),
#  ('Awakening', 'Special%20EFX'),
#  ('La%20Casa%20I', 'Kreidler'),
#  ('Foot%20Work', 'The%20Hippy%20Boys'),
#  ('In%20Faith%20With%20You', '1.000%20Mexicans'),
#  ('Abandon%20Ship%20%5BBBC%20Radio%201%20Live%20Version%5D', 'Gallows'),
#  ('Will%20You%20Please%20Spend%20New%20Year%27s%20Eve%20With%20Me%3F',
#   'Allo_%20Darlin%27'),
#  ('L%27Axe%20Du%20Mal%20Malax%C3%A9', 'La%20Descente%20Du%20Coude'),
#  ('After%20Midnight', 'Eric%20Clapton'),
#  ('Vertrouw%20Maar%20Op%20Mij', 'Gordon'),
#  ('Cover%20Dub%20%28Dub%20/%20Instrumental%20Reggae%20Music%29',
#   'Mikey%20Dread'),
#  ('Vernon', 'Storybox'),
#  ('Monsters%20%28Soundtrack%20Album%20Version%29', 'Hurricane%20Bells'),
#  ('The%20Driveway', 'Miley%20Cyrus'),
#  ('Ramesses%20II', 'Ramesses'),
#  ('Liberation', 'Junior%20Delgado'),
#  ('Xina', 'Mergel%20Kratzer'),
#  ('Tallyman%20%282005%20Digital%20Remaster%29', 'Jeff%20Beck'),
#  ('Nightmares', 'A%20Flock%20Of%20Seagulls'),
#  ('Be%20Careful%20Not%20To%20Be%20Too%20Careful%20-%20Album%20Version',
#   'Patrick%20Nuo'),
#  ('Oh%20Na%20Kuri%20Labdi', 'Sukshinder%20Shinda'),
#  ('Look%20At%20%27Im%20%28LP%20Version%29', 'Mabel%20Mercer'),
#  ('Rude%20Boots', 'Burning%20Babylon'),
#  ('Symphony%20in%20Gminor', 'Phalanx'),
#  ('Las%2040', 'Sergio%20Vargas'),
#  ('Moc%20slowa', 'Mesajah'),
#  ('Here%20I%20Am', 'SOJA'),
#  ('NO%20CHANGES%20IN%20MY%20LIFE', 'Alpha'),
#  ('Better%20Days', 'Bruce%20Springsteen'),
#  ('Betta%20my%20Space', 'DJ%20Rashad'),
#  ('No%20Other%20Way', 'Classix%20Nouveaux'),
#  ('String%20Quartet%20No.3%20in%20D%20major%20Op.18%20No.3%20%3A%20I%20Allegro',
#   'Endellion%20String%20Quartet'),
#  ('Vete%20De%20Aqu%C3%AD', 'Merche'),
#  ('Such%20A%20Night', 'Johnnie%20Ray'),
#  ('Forget%20About%20It', 'Alison%20Krauss'),
#  ('El%20Cuento',
#   'Jos%C3%A9%20Alfredo%20Jimenez%20Con%20Acompa%C3%B1amiento%20Del%20Mariachi%20Vargas%20De%20Tecalitlan'),
#  ('Ja%20Die%20Giraffen', 'Lena%20%26%20Die%20Jamba%20Band'),
#  ('Bonfires', 'Hope%20Of%20The%20States'),
#  ('Baker%20Street', 'Carnival%20in%20Coal'),
#  ('The%20Loneliest%20Person%20I%20Know', 'Splender'),
#  ('At%20The%20End%20Of%20The%20Day%20%28Explicit%29', 'Marion%20Raven'),
#  ('Fill%20the%20Earth', 'Ron%20Kenoly'),
#  ('You%27re%20Too%20Hot%20%28Explicit%29', 'Deborah%20Harry'),
#  ('Knowledge%20And%20Wisdom', 'Kotipelto'),
#  ('Picture%20Frames', 'Splithabit'),
#  ('Turn%20To%20Dust%20%28Remix%29', 'Crash'),
#  ('Iceland', 'Neviss'),
#  ('Columnist', 'Your%20Enemies%20Friends'),
#  ('lattitude%20instrumental', 'Five%20Deez'),
#  ('Keep%20Coming%20Back%20%5BLive%20In%20Nashville%5D', 'Marc%20Broussard'),
#  ('Mod%20Lang%20%5BAlternate%20Mix%5D', 'Big%20Star'),
#  ('Gumby%20Killed%20the%20Dinosaur', 'Pumpkin%20Buzzard'),
#  ('Three%20Witches', 'Epidemic'),
#  ('Cerulean%20Transience%20Of%20All%20My%20Imagined%20Shores',
#   'Disembowelment'),
#  ('Around%20My%20Wrists', 'The%20Holiday%20Plan'),
#  ('Son%20Song', 'Uzeb'),
#  ('Nostalgia%20Amnesia', 'Viola'),
#  ('Some%20Bizzare', 'Agressiva%2069'),
#  ('Casio%20Jawn', 'Technicolor%20with%20Flowchart'),
#  ('Super%20Going', 'Boredoms'),
#  ('Express%20Yourself', 'Cold%20Sweat'),
#  ('Matter%20of%20Fact', 'Doug%20Hoekstra'),
#  ('Can%20You%20Hear%20Me%20%28LP%20Version%29', 'Lila%20Mccann'),
#  ('Oh%20Christmas%20Tree', 'Nelson%20Rangell'),
#  ('Bleib%20Anders', 'Marc%20Depulse'),
#  ('Red%20Stripe%20%26%20Heineken',
#   'Easy%20Star%20All-Stars%20Featuring%20MC%20Trouble'),
#  ('This%20Is%20Real', 'Asher%20D'),
#  ('Medusa', 'Asphalt%20Jungle'),
#  ('Love%20changes%20everything', 'Novaspace'),
#  ('My%20Baby%20Loves%20Me', 'Charlie%20Gracie'),
#  ('Until%20The%20End%20Of%20Time', 'Supreme%20Majesty'),
#  ('HNB', 'Video%20Nasties'),
#  ('%C2%A1Lo%20Mato%21', 'Peret'),
#  ('Allerdings%20Otros%20Aires', 'Otros%20Aires'),
#  ('The%20Commandments%20%28Acappella%29',
#   'Afterlife%20featuring%20Matti%20Dinah'),
#  ('Steelo', '702'),
#  ('Keep%20It%20Home', 'Blind%20Blake'),
#  ('Enden%20av%20november', 'Kaizers%20Orchestra'),
#  ('One%20Thing%20%28The%20Secret%20Of%20Time%20Album%20Version%29',
#   'Charlie%20Peacock'),
#  ('One%20Day%20%28Soul%20Relation%20Mix%29',
#   '2%20Brothers%20On%20The%204th%20Floor'),
#  ('Kolysanka%20Karolinki', 'Mikromusic'),
#  ('New%20Holes', 'Doug%20Stanhope'),
#  ('Crush', 'The%20Smashing%20Pumpkins'),
#  ('Someday', 'Lord%20Creator'),
#  ('Logan%20Braes', 'Deaf%20Shepherd'),
#  ('The%20Break%20Up%20Song%20%28Live-Milwaukee%29', 'American%20Hi-Fi'),
#  ('Locks%20a%20Grow', 'Queen%20Ifrica'),
#  ('Tell%20It%20To%20My%20Heart', 'Renegade%20Hit%20Makers'),
#  ('September%20Song', 'Carla%20Cook'),
#  ('Valvoline', 'Scout%20Niblett'),
#  ('I%27ve%20Got%20The%20Music%20In%20Me%20%28Dreaming%20In%20Color%20Album%20Version%29',
#   'Jump5'),
#  ('La%20fuga%20de%20Ruben', 'La%20Barranca'),
#  ('Toro%20Mecanico', 'Dinamita%20Pa%20Los%20Pollos'),
#  ('CZEGO%20TY%20%C2%AF%C2%A5DASZ', 'Shazza'),
#  ('Mystic%20Voice', 'THE%20CHIFFONS'),
#  ('Canadanada', 'Johan%20Skugge'),
#  ('Midnights', 'Lost%20Valentinos'),
#  ('A%20Better%20Home%20In%20The%20Phantom%20Zone%20%281999%20Digital%20Remaster%29',
#   'Bill%20Nelson%27s%20Red%20Noise'),
#  ('The%20Orphan%20Girl', 'Buell%20Kazee'),
#  ('Theme%20De%20Yo-Yo%20%28Radio%20Edit%29', 'Su-Paka-Pooh'),
#  ('Walk%20On%20The%20Wild%20Side', 'Lou%20Reed'),
#  ('It%27s%20Love%20%28from%20Wonderful%20Town%29',
#   'The%20Original%20London%20Cast'),
#  ('Parle-moi%20encore%20de%20toi', 'Audrey%20Gagnon'),
#  ('The%20Moon%20Is%20A%20Harsh%20Mistress', 'Tone%20Damli%20Aaberge'),
#  ('Sho%22%20Nuff%20Sold%20On%20You', 'Delegation'),
#  ('To%20The%20Negative%20Power', 'Dim%20Mak'),
#  ('You%20make%20me%20wonder%20%28Beats%204%20U%20Mix%29',
#   'Celebrate%20The%20Nun'),
#  ('govinda%60s%20house%20%28Chris%20Nagle%28Original%20%2787%20Mix%29%29',
#   'Suns%20Of%20Arqa'),
#  ('Jesu_%20Joy%20Of%20Man%27s%20Desiring%20%20%28Christmas%20Album%20Version%29',
#   'Rebecca%20St.%20James'),
#  ('Get%20Lost', 'Patrick%20Wolf'),
#  ('All%20Would%20Envy', 'Chris%20Botti%20%28featuring%20Shawn%20Colvin%29'),
#  ('Aranjuez', 'David%20Palmer'),
#  ('Tower%20Of%20Babble%20%28Featuring%20Smut%20Peddlers%29', 'Copywrite'),
#  ('Across%20The%20Sea', 'The%20Samples'),
#  ('A%20Soft%20Place', 'Halo'),
#  ('Vocal%20Intro%20%28Imagine%20a%20Nation%29', 'Terry%20Callier'),
#  ('You%27re%20Taking%20My%20Heart%20%28Gordon%27s%20Golden%20Extended%20Dance%29',
#   'Haddaway'),
#  ('Country%20Music%20/%20Mexican%20Cowboy%20/%20Tough%20Cowboy',
#   'Pablo%20Francisco'),
#  ('Sexy%20Funky%20Body', 'Marusha'),
#  ('Blue%20Days%20%28Dias%20Azuis%29', 'Lee%20Ritenour'),
#  ('Walking%20In%20Memphis', 'Master%20Blaster'),
#  ('Suddenly', 'BT%20feat.%20Erire'),
#  ('Along%20the%20Way', 'Devotchka'),
#  ('Shattered%20Cross', 'Darrell%20Scott'),
#  ...]

# %%
# bz2 compression
import bz2
data = json.dumps(track_data['0nbm4bvneAGlrp5wZKRHT8']).encode('utf-8')

# %%
c_data=bz2.compress(data)

# %%
len(c_data)
# Out:
# 80815

# %%
# bz2.decompress(c_data)

# %%
track_data['0nbm4bvneAGlrp5wZKRHT8']['meta']
# Out:
# {'analysis_time': 7.42932,
#  'analyzer_version': '4.0.0',
#  'detailed_status': 'OK',
#  'input_process': 'libvorbisfile L+R 44100->22050',
#  'platform': 'Linux',
#  'status_code': 0,
#  'timestamp': 1444734951}

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-74-ec8fdd1cd630> in <module>()
# ----> 1 import pymongo
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-3.5.1-cp36-cp36m-macosx_10_6_intel.whl (300kB)
#     100% |████████████████████████████████| 307kB 1.8MB/s ta 0:00:01
# Installing collected packages: pymongo
# Successfully installed pymongo-3.5.1

# %%
import pymongo

# %%
client = pymongo.MongoClient()
db = client['song_db']

# %%
col = db['songs']

# %%
col.insert_one(track_data['0nbm4bvneAGlrp5wZKRHT8'])

# %%
col.stats
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'song_db'), 'songs.stats')
